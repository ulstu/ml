# %% [markdown]
# # Character-level text generation with LSTM
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2015/06/15<br>
# **Last modified:** 2020/04/30<br>
# **Description:** Generate text from Nietzsche's writings with a character-level LSTM.

# %% [markdown]
# ## Introduction
#
# This example demonstrates how to use a LSTM model to generate
# text character-by-character.
#
# At least 20 epochs are required before the generated text
# starts sounding locally coherent.
#
# It is recommended to run this script on GPU, as recurrent
# networks are quite computationally intensive.
#
# If you try this script on new data, make sure your corpus
# has at least ~100k characters. ~1M is better.

# %% [markdown]
# ## Setup

# %%
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import random
import io

# %% [markdown]
# ## Prepare the data

# %%
path = keras.utils.get_file(
    "nietzsche.txt", origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt"
)
with io.open(path, encoding="utf-8") as f:
    text = f.read().lower()
text = text.replace("\n", " ")  # We remove newlines chars for nicer display
print("Corpus length:", len(text))

chars = sorted(list(set(text)))
print("Total chars:", len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i : i + maxlen])
    next_chars.append(text[i + maxlen])
print("Number of sequences:", len(sentences))

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# 614400/600901 [==============================] - 0s 0us/step
# Corpus length: 600893
# Total chars: 56
# Number of sequences: 200285

# %% [markdown]
# ## Build the model: a single LSTM layer

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(maxlen, len(chars))),
        layers.LSTM(128),
        layers.Dense(len(chars), activation="softmax"),
    ]
)
optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss="categorical_crossentropy", optimizer=optimizer)

# %% [markdown]
# ## Prepare the text sampling function

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ## Train the model

# %%
epochs = 40
batch_size = 128

for epoch in range(epochs):
    model.fit(x, y, batch_size=batch_size, epochs=1)
    print()
    print("Generating text after epoch: %d" % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print("...Diversity:", diversity)

        generated = ""
        sentence = text[start_index : start_index + maxlen]
        print('...Generating with seed: "' + sentence + '"')

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.0
            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
            sentence = sentence[1:] + next_char
            generated += next_char

        print("...Generated: ", generated)
        print()
# Out:
# 1565/1565 [==============================] - 194s 123ms/step - loss: 1.9193
#
# Generating text after epoch: 0
# ...Diversity: 0.2
# ...Generating with seed: "ch has hitherto been the secret wish and"
# ...Generated:   the self-and in the will of the forthing in the of the presente of the self-and the self and the simely and still and the self-will of the more the see and the precessing the self-and the power the more the propers of the his of the seems of the seem and the self-and has in the forthing the self--and in the forthing of the morals of the presente of the seem the seem the his out of its for are the
#
# ...Diversity: 0.5
# ...Generating with seed: "ch has hitherto been the secret wish and"
# ...Generated:   and himself himself is the consermanness of a one himself is itself the intendent of an her of the for intime of the world be living for she world the world has the conticual the seen itself will have the respensed for an thereffrenom of the proncess of the perhaps as her his in the see not and and his has an in pirerest and are of will still the for the hisher which an any and the mare and enoug
#
# ...Diversity: 1.0
# ...Generating with seed: "ch has hitherto been the secret wish and"
# ...Generated:   tooghing; to inhaed to ores where rismition all infllcioun sciutuated friends as to word gen and into this mafter for whine. therpur is the ; lew. and, thoughing. in not revevilo ortom kind, which co is the "servat, to dockince of the read maired, thing hon of notic thably the have forttings prachusienibab dremsinescing or then nature of inperhaps has elang deed, and one. its of not mand itself m
#
# ...Diversity: 1.2
# ...Generating with seed: "ch has hitherto been the secret wish and"
# ...Generated:   forgable the moaling is -orfernbyekd. show dalse b to iniclused a liminamen,--wes decichtle carize, respals, postible ligho!. them and carlar, world and foolabye as is volsfopet not in thareever which lic meann howevin or an w" and lorgelved ocikeally the had religiatate of the kind, eays," of the might, is-note rechlegibies tan (pand of cratnercely"--becapesmantes. mysed to the fluf of nshonty,
#
# 1565/1565 [==============================] - 194s 124ms/step - loss: 1.5679
#
# Generating text after epoch: 1
# ...Diversity: 0.2
# ...Generating with seed: "nating kings for the people, while their"
# ...Generated:   strengt the self-despecting the self-sublime to the despect and the present of the procis in the deems to the conditions and the deception of the spiritual to be possibly to the consequently the deems to the spiritual of the self-such and and the spiritual to the conditions of the saliss of the deems to the spiritual and to the deems of the strengt to religious and the contrary the conditions and
#
# ...Diversity: 0.5
# ...Generating with seed: "nating kings for the people, while their"
# ...Generated:   every self-devilons of the can restrastity of stand of the real the distradical has man.--there is a still the that is because the the seem of the such a present perhaps of its one of the does the repers to be the conditions to encent and a takes from the conditions and derently interpress of the amill the uncritring don that the constitutions of possibly the plareful to his hound that the extent
#
# ...Diversity: 1.0
# ...Generating with seed: "nating kings for the people, while their"
# ...Generated:   have behown inflictinests. is my, at the greating wild or at and beto wold as wayceness in themselves of evil is a would religious assurf of strantthing the soluture.. it is seeveronal pirta can pans to anbysel's by its bettrictings the dreated en mearinish, or being with hvan ween betre-tbus emboiness, freesplessh--hat say the leas, thereby fromloncerr. every have as time theor a mike man; out a
#
# ...Diversity: 1.2
# ...Generating with seed: "nating kings for the people, while their"
# ...Generated:   be secenation"--he that horthing wordeen. i e "accordingod back passions mothosk bnehaues and hithert. lea prease, meand by remlowed to ccmorraisness, ejtact to sem forming." nover0fy eairh whatever, easymbuaxde--loves as independing evoan filled, tow.n" smazimes smalk that the dalifingstary one tascing grawn alty morality..why mabismers can verconaty would the dobutr! like and all everych myseff
#
# 1565/1565 [==============================] - 195s 124ms/step - loss: 1.4815
#
# Generating text after epoch: 2
# ...Diversity: 0.2
# ...Generating with seed: "rdained hunting-domain for a born psycho"
# ...Generated:  logist of the sense of the work of the problem of the subject of the profound and and the something the sense of the sense of the sense of the spirit of the supersomed that is the problem of the seems to the conscious in the species and the seem and the serious and the sense of the conscience that is a prise in the subject that the self-derated that is not the serious and and and that is a present
#
# ...Diversity: 0.5
# ...Generating with seed: "rdained hunting-domain for a born psycho"
# ...Generated:  logisted to suffer that is not seems of its are not because that is not conscience to be a still be subject of moral probably that has long that will that it was such a sensible command that is therefore the schopenhally perhaps to esecmeal forgs to the profound in all than an intime that the great suffering that is nature should in this man is reals and the any spirit of the most compartions of w
#
# ...Diversity: 1.0
# ...Generating with seed: "rdained hunting-domain for a born psycho"
# ...Generated:  logist resellly longer, wills movements and more natration sand the most he does i manntheration of man arorm, with the crust conscirety, and two person and oral less schopored of philosopher is also have bat preha; he belief enoughe, deelsness groud truth, and science: new fact, metepyity of freedom that pliarorty? the loughing, of power, not i powerstio that which cause had is as which he is he
#
# ...Diversity: 1.2
# ...Generating with seed: "rdained hunting-domain for a born psycho"
# ...Generated:  cliness, and , the dislask "blind, man s.cruatjume on man is mostdeoc erreally of order wo will: rogal pleasing two cause last deruce min than spirint: will phoverace., such suredry is always: we say metaparily, what, custought inlitrandat god" thought. this natrese. no rali=,t-weled, of riligity hidher of ganners :  virition-inardas"; but who viewue trinary min".--they repropbed buch, "greats a t
#
# 1565/1565 [==============================] - 193s 124ms/step - loss: 1.4357
#
# Generating text after epoch: 3
# ...Diversity: 0.2
# ...Generating with seed: "eby to put an end to the frightful rule "
# ...Generated:  and an and the sentiment of the sentiment of the procising the proper of the proper to a served and the senting and propers and propers to the some end in the some enting and proper to the conscience and an and the senting and the sentiment of the seems to a morality to the senting, the some experience of the propers and conscience and the do with the possible and the propers to a philosophers and
#
# ...Diversity: 0.5
# ...Generating with seed: "eby to put an end to the frightful rule "
# ...Generated:  and complaises the soulations of in the only the consequently and even the perhaps to the spiritual conscience to a conscious of the standards of the most such a religiously in the properions and something of intellectual the satters to all still liver and in the woman in in the contrading in their experience for a most and only sense, and in the sentiment which in short and the hold reasing for w
#
# ...Diversity: 1.0
# ...Generating with seed: "eby to put an end to the frightful rule "
# ...Generated:  which may be the consequence which a promisisforden introlofoxe wis under over very doubthomed and mahtering, grounds outsad yourg confect that another soulal and free, especially distancion in its chtrlapling that is badbious readered lastained, the malingary ires unsisterity the nowahance always were as the enting sfeter werness to both verourding!                1. the fact to away enport loveo
#
# ...Diversity: 1.2
# ...Generating with seed: "eby to put an end to the frightful rule "
# ...Generated:  freable me; for tasks! "  stutwim," therefore anougth.       eccsspichatormarianly," but oo again grdound ared--this all bentided that consection. fundeerh! condicam mortivated shouch stepicant, and even cobre special its neigomver nagaach in a conturnourth, even their stindy himself the sentures, xt foullated not cannifer that br out of cuncephilening rist" indoenous drand your ugens somewesougr.
#
# 1565/1565 [==============================] - 195s 124ms/step - loss: 1.4063
#
# Generating text after epoch: 4
# ...Diversity: 0.2
# ...Generating with seed: "rought it, he the timely friend,      th"
# ...Generated:  e soul of the such a some and the soul of the world of the present and the sense of the most the individual the the world of the most the the and the present and devenies that the such a some stands of the soul of the art of the world of the world of the present and always and the soul of the same and the world and the world of the present and the such a present and the the the world of the things
#
# ...Diversity: 0.5
# ...Generating with seed: "rought it, he the timely friend,      th"
# ...Generated:  ose the the succuble that which all that and an extent the some most themselves the success of the most still upon the standards and things is the be at is it would no longer and this still be the lateric and the other his own in this it is the world in the present standard in the preasurd the slive has the the woman, for this he ever to be the punished to which has so who has the possibility of t
#
# ...Diversity: 1.0
# ...Generating with seed: "rought it, he the timely friend,      th"
# ...Generated:  e decerning--the distascuan womand happeled they cannese, t. so and not under awaghtd of the lowed of profoundializerations irvery really upof even hbitied beatter, that cannotal. the to prousitic therever hechter entable to which presensed in ever transbapery of it wills it those is comdusive inne--but the lelknt are the wollt-be-latrer less whate means of this is aquiman guiltures the pridrition
#
# ...Diversity: 1.2
# ...Generating with seed: "rought it, he the timely friend,      th"
# ...Generated:  ere it has in dives to art of which houreding, in heady or alromalnisad spe.igling, theer to uawhece "malned: the historic in should. nawo-mbalus the sodess, any ivery theschion which favouryism,.whan thas as to for?. for dreaded traditionaly, of task in plumous that virtue of well suprivational life, drantifild its lawakns--a plances thas "gor highefoush of age all thmoble behi of european are do
#
# 1565/1565 [==============================] - 194s 124ms/step - loss: 1.3838
#
# Generating text after epoch: 5
# ...Diversity: 0.2
# ...Generating with seed: "avour of the temperate men? the "moral"?"
# ...Generated:   and the sense of the sense of all the sense of all the see a sense of the any in the some sense of the sense of the see to an endurion of the sense of the sense of all the spirit and sense of the sense of the sense of the contempt of the sense of the sense of a such a strength and sense of the sense of the sense of the such a things and sense of the conceited and also of the sense of a contempari
#
# ...Diversity: 0.5
# ...Generating with seed: "avour of the temperate men? the "moral"?"
# ...Generated:  --and itself in the father inservation and man of some personality of the endurions, and what be the logic action of the most conternal christian spirit with the strength in the contemporant and greatest instinct who has perhaps even itself as the some stands of the seem be the understanding and instance, in a man of seems to the stands of the world, the most moral more prove the concerned and con
#
# ...Diversity: 1.0
# ...Generating with seed: "avour of the temperate men? the "moral"?"
# ...Generated:   in the such upon adapt, light and untrulted the physt of can been dangerous "simpl" to sin is you have or unexabotucting become origican concern sabsus in fearmity wat whan to influence in the present from higher smorgs itself subpresence, no longer the restrangush not rewalt worth, not them that attain lellen. the lofestory. you asseveristic as it can e has still more men peyence are worth, as n
#
# ...Diversity: 1.2
# ...Generating with seed: "avour of the temperate men? the "moral"?"
# ...Generated:   in that still called nature, or from prespect: sacrosses know the gemman was akem wel biddish, a. kno awoudocmally anvence parce are rugountable; such spectodly, for the very neithesty.=--but rwed, of tice .afopis oncy," effectmory becalce, fundamental the curentness; hell, their christianity count nor ligh futuressecon when know wese trungrout wrought, unhars more trute by things; (this belong w
#
# 1565/1565 [==============================] - 194s 124ms/step - loss: 1.3665
#
# Generating text after epoch: 6
# ...Diversity: 0.2
# ...Generating with seed: "s frightfully entangled, the genius of t"
# ...Generated:  he still the conscience that we are and the consideration to the strange of the sublime that is the conception of the consideration of the conception and such a still and precisely the strength of the conscience, in the strength of the really be the conscience that is the conscience to the constitution of the strange and one is all that is not an and as a sublime and conscience, and consideration
#
# ...Diversity: 0.5
# ...Generating with seed: "s frightfully entangled, the genius of t"
# ...Generated:  he end, stranger--that he have been good conscience, conceitation that which the stands and constitutes of great chare, a to the case of the strange of interpretes and must be the conceptions of the conditions of the prinction of the logical and the result of constitution of the great good and forearily to all the sublime of wied to chare because of every will be conscience the first be the rule,
#
# ...Diversity: 1.0
# ...Generating with seed: "s frightfully entangled, the genius of t"
# ...Generated:  he great through our (nature and nature of maintained organism, if sumen.   ig "those soul, unnethisd--elabaried, babless yearnic still ever ancient so ranguire in that can the lost was son his antixeed for still assimality. whatever, droming cause.  2y and for a pastient wvaiker the recognition of gurs stindliur, refirence are morabline very starts, to a man, are one remained men)--the derking an
#
# ...Diversity: 1.2
# ...Generating with seed: "s frightfully entangled, the genius of t"
# ...Generated:  hese "overly be the excessive asone refinly--one in r,tiesximen; indeed, disclusion dare civhen paints, sympathhar lifenationally,  , as air not ca him iacion certuneary meshomeimed one"--power a nother rages, self-munimant, and precition triun, alore sorial with the future; the entire in which, is more, incalndue, difficulty, bro xciansmen? he-r,thaught prellined encougnt him, "fin; apprave livig
#
# 1565/1565 [==============================] - 193s 123ms/step - loss: 1.3504
#
# Generating text after epoch: 7
# ...Diversity: 0.2
# ...Generating with seed: "ings and doings are, at bottom, acts of "
# ...Generated:  the conception of the spirit of the spirit of the self-enting and the strength of the final stands of the sentiment in the sacrificed to the soul of the sense--and the sense of the said a sentiments of the such a seriously of the spirit of the order of the sense--and the sacrificed to the sentiment the sacrifice of a self and the sense--and the sense--and the sense of the sentiments and concerning
#
# ...Diversity: 0.5
# ...Generating with seed: "ings and doings are, at bottom, acts of "
# ...Generated:  the look of the superficial disciple and at any the end the sense, and the truths of the sense--and the present and the species of the prevaled and influence of a strange of the sentiment, there are such the spirit of a sense of the painful understands the ordinary and superfoctity of delight when they we greatest, for the ordist fore, so dangerous a stands of the spirit of the port, at the philos
#
# ...Diversity: 1.0
# ...Generating with seed: "ings and doings are, at bottom, acts of "
# ...Generated:  mannerantion in order to the enterhal selitt to a fabling to a signefultid son faolure. the truem is does the extralica very vanity. easy oneen-worst of the concerning prolimets of same wish acrical cleeg namification, their missome! and finer the prise that our concerning such after the something puentely right belong centurist round" and on the counterfen--i essential   orepor manifered rescerni
#
# ...Diversity: 1.2
# ...Generating with seed: "ings and doings are, at bottom, acts of "
# ...Generated:  old drising. whatever oodnesses, thereby cain an propead" anbocord now to it, the herd that is the ucited the gholgen have results prexe walling, but europe." are or which whas its resistsmed not in the orfarian, at everythers us, emposition after would ne ," the science. leve absurd science also tod shrict one is pastmicatation, narking there are fase for gived tobals! superful,-no were welf" par
#
# 1565/1565 [==============================] - 197s 126ms/step - loss: 1.3387
#
# Generating text after epoch: 8
# ...Diversity: 0.2
# ...Generating with seed: "nism" usque recurret. [footnote: horace'"
# ...Generated:  s procasuss," and the strength of the sense--as the sense--as the same believe the procought of the soul of the soul of the some es to all the sense--and the spirit of the procought of the same man; the sense, and have the world and the see in the former and probably and and the strength of the sense--and the fact to the senses of the procasus of the sense--and the traditional only and the see and
#
# ...Diversity: 0.5
# ...Generating with seed: "nism" usque recurret. [footnote: horace'"
# ...Generated:  s signification of the externally about instinct in the soul of the see heart of the protection of a possibles and recoguination of the soul of the problem of one to the prose that a time the man in mankind only are and actually for individual world to the fact to the condition of the probably only with everything the proposition of the same german danger as a deold the domain of the subtariatic p
#
# ...Diversity: 1.0
# ...Generating with seed: "nism" usque recurret. [footnote: horace'"
# ...Generated:  s judgment is for new levents, in him. in curioarly, dustorclect good sacrificing, in oldordikes effirace and alteracrited, tho dace that only always trat of soy, in his own know that is sign, the precisely who latters and more proble a thise of all inclins, only hation. the reclised those distaviaved to the histor jusgss defuct the opposingy, suffers of goody to one, he eslamile individual concep
#
# ...Diversity: 1.2
# ...Generating with seed: "nism" usque recurret. [footnote: horace'"
# ...Generated:  s dispreution virtts and higher.   5. in mirewsllay of hitherto onew cause--ghis. yotherevery fear, as it power mustwwpeving uscitars nowad yow with the seperation of morally pract, enchabil to killd and clarding or eoratode; men among again closes acd how nothing ladged as not actual the the rited agaunity mind grantated done! in histor, and imperious certaining one coursh! as into the such macti
#
# 1565/1565 [==============================] - 197s 126ms/step - loss: 1.3271
#
# Generating text after epoch: 9
# ...Diversity: 0.2
# ...Generating with seed: "hat very account dupers also? _must_ we "
# ...Generated:  and the properly and the delight of the spiritual consciousness of the spiritual to the process of the delight of all the most superiors of all the spiritual experience of the spiritual strength of the same the spiritual to the precisely to the same the same one of the most all the same in the spiritual courage and all the superstities of the family of the spiritual constant and and the soul of th
#
# ...Diversity: 0.5
# ...Generating with seed: "hat very account dupers also? _must_ we "
# ...Generated:  theness to be soul of the possible. the same one who are a great world we have to be takes and intellectual the comprehensive the continged to the basis him who is his souls with the will of the logical possible: in the spiritual even with the state of a possess of the varies of all produced the let the dain and experiences to all the higher at all, only that is wishent comprehension of superiory,
#
# ...Diversity: 1.0
# ...Generating with seed: "hat very account dupers also? _must_ we "
# ...Generated:  are discoveral abwayt belie and evil it is nature freeedf--theobounded and betterthmen, imposes this great hate be the raghere, a truth under the pholive different into his kind of all things of seeme?"--"morely up it not not on-dream when "creation")--but its conscience him, wether times, granking intentional refinite sympathy! forge?" has been otheristical..=--womk" and christian first sole begi
#
# ...Diversity: 1.2
# ...Generating with seed: "hat very account dupers also? _must_ we "
# ...Generated:  be genion but, from all, dire mustrable singuly. no 'nonem, they is himself vicitsegen. un-theies for a greaterp, for 1finding! just i yhelp tastems because to the rided of an agctseduamly adcition of all that, nucts--it is baring such ciyed as it is the s maves that problem , it is sought. now s, gime nolleinative fallenell, thus desprofing, mu, attached. and obdiniouxfrough very master!" you fav
#
# 1565/1565 [==============================] - 197s 126ms/step - loss: 1.3179
#
# Generating text after epoch: 10
# ...Diversity: 0.2
# ...Generating with seed: "dge is thereby made. instead of the cons"
# ...Generated:  cience and also and the subjects of the subjects of the subjects of the spirit and also we are the subjecting and also and the subjection of the strength and all the strength and also the supersords to the strength and the strength and the and the something to the supersord and the subjection of the subjection of the subject of the present and strengt of the subject of the sense" and an ancertal s
#
# ...Diversity: 0.5
# ...Generating with seed: "dge is thereby made. instead of the cons"
# ...Generated:  cience of the spirit and marting and you of the man sense" with pleasure also believer, and can the same will to many and an appear to the properal soul. and in order to the courage of a consciously end in the religion of the sense, in surters as to have to be discreases the subject. that it is the word in their hand, the man who stand the subjects of the present and find the most great universoul
#
# ...Diversity: 1.0
# ...Generating with seed: "dge is thereby made. instead of the cons"
# ...Generated:  ust of whacs its notion in which is for in one comes to himre-man, and came in these influence mamen judgment. this deglimance, on the only highed pleasure), with retarise that it take would degre, whethershoveratime enight of fact, it werked on the clanixm of been suffering?" how too, suprosing a of the possessions are tamuse man no mufteorence cruelty, that the philosophicaler and as rahe midd m
#
# ...Diversity: 1.2
# ...Generating with seed: "dge is thereby made. instead of the cons"
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """
# ...Generated:  enser? ever sustring. perhaps a fears incommon indivinity, ideal and tneil--the means, and it one honormouss, and concern forget typelous atcomsfrochted, conscioralization in affording thety is tune to trease of, when to credame willing; it cannot insaltanted the fundamable, as schoil tohile. the powerfunly deverie cistutifa, when threedor of its worm pro!nelianity must morough form suld principe
#
# 1565/1565 [==============================] - 192s 123ms/step - loss: 1.3094
#
# Generating text after epoch: 11
# ...Diversity: 0.2
# ...Generating with seed: "" so he would like to have some hundreds"
# ...Generated:   of the striving to the contrast of the standards of the prompted and all the prompted in the other the more the present and the prompted and the and the comprehension of the ancient the contemple and the world of the standards of the philosophers and the state of the prompted to the more and the standards of the prompted and the contrast of the prompted and the such a still be the strivin of the
#
# ...Diversity: 0.5
# ...Generating with seed: "" so he would like to have some hundreds"
# ...Generated:   of the rest and of the unifinction of self-respectably possibly and his powerful into the morality of the presented to the will and the life, and the any of suffer the interpretes and the must them of the fact them with and regard to reason the is the whole standards of still mind and bemose to the sense, in its basis has or the love of the might and all that ethics perhaps to discover, the stand
#
# ...Diversity: 1.0
# ...Generating with seed: "" so he would like to have some hundreds"
# ...Generated:  , who were thereby volitions, and throughormans wencued not been misgle-gumanme--natle that he gaus tifed may grow a philosophers fell beainly, and cien if aviden ease, some spirit to s from a man,-it cannot latter--in caremed to be no takes "from feelings. with the difaterness of most be successjust and new connugled oney rogrious other line!  walt that immense for it in the preyce of the s.the f
#
# ...Diversity: 1.2
# ...Generating with seed: "" so he would like to have some hundreds"
# ...Generated:  uality of arclined with know this aptron. mysteematicy it been greatest ideastic go allow the tragedly drexisn or suffer, we are ir" pe: not be turns who to munify, with the very individual frather--oome"s remods to side noeby case of is as its to genedothy, is good men, conceptionaling about think a truth, over woromy undermosterness at is new asever and due of the sagorshmenity. that things--the
#
# 1565/1565 [==============================] - 196s 125ms/step - loss: 1.3038
#
# Generating text after epoch: 12
# ...Diversity: 0.2
# ...Generating with seed: "e finds a very remarkable man.  138. we "
# ...Generated:  are such a believe the constitute and the world of the subjection of the constitute the dangerous and account of the moral constitutely and the saint the say of the constitutely and the world of the says of the say of the constitute the constitute of the subjection of the constraint of the subjection of the subjection of the such a probable and an order to the constitute the man who has been the s
#
# ...Diversity: 0.5
# ...Generating with seed: "e finds a very remarkable man.  138. we "
# ...Generated:  are cause the "good" is the "spirit" of detined the revence of a restctles of the state of probably revendery, there is not have where it is the saint as the christianity of nature the experience of the experient that the meants of the new man science, an omen as it was a far with the act in the order of such a means of means of some out of a sour of the greatest and devils that can be new of whic
#
# ...Diversity: 1.0
# ...Generating with seed: "e finds a very remarkable man.  138. we "
# ...Generated:  to usue of the contrary, easy words lows which there are unsmempation of human of the revels, of the general sure them: that more culture his painfully, firelating if it is fundentablre thereander-like, only as itself. where think them? suppier strong? of the plaushes of soul: moralipe"; perhaps only the most intercarating in according addlood does he relight must queste ourselves with swigh furth
#
# ...Diversity: 1.2
# ...Generating with seed: "e finds a very remarkable man.  138. we "
# ...Generated:  gods when is can dansy; have a chors and as no in the rathers of hinden spirities after reasons. that is hand, denigsful much nature further are shepetly: therefore, "mana-e""!paliss: min ther-not blood, go sa: they meant in learning of pain the mankind and much. and then draged a tlusm-greated intengpory, and european incertacles exceptions,  we down us, associs whomf laiging which it is enly by
#
# 1565/1565 [==============================] - 200s 128ms/step - loss: 1.2958
#
# Generating text after epoch: 13
# ...Diversity: 0.2
# ...Generating with seed: "all the sick and suffering, which means,"
# ...Generated:   and with a soundly and action and a senses and all the most delight of the power of the process of the subjection, and the most subject of the subjection of the sensations. the most subject, and and the senses of the subject of the subject of the subject, the senses of the subject of the most discover the subjection of the spiritual consequences of the subjection of the spirit to the subject of t
#
# ...Diversity: 0.5
# ...Generating with seed: "all the sick and suffering, which means,"
# ...Generated:   as the moral interception of the spiritual and missting to the spiritual being of it with the problem of the only a form of the moral conscioustian and the order of the most religion of the little and rebless of men which is the problem of the origin of his moral the language of the science, and a moral interned and problem and intement, the last himaness of philosophy and often be subjzzating ar
#
# ...Diversity: 1.0
# ...Generating with seed: "all the sick and suffering, which means,"
# ...Generated:   the wayn faveness for the virtuinis of the wopsty of men, men forght for powers of disdect to and to him. we can that the variational presiblers of sciences--arbited theresipe--and of its sense, not oppose with protsting. one a bodded and flow only is who with their mess man we beneful of the knewers--why in which like for a everything of the futurely eyes, and like nordings man arisents in every
#
# ...Diversity: 1.2
# ...Generating with seed: "all the sick and suffering, which means,"
# ...Generated:   o! so mus waitis this instrutioaw uter, it is live conterpative the existences would be entess, throughedss of he honest embyrad case asias : leend the tober peraling imprete if, as a rest blooke ouihly ins tele to bearly.. forr dasee and dissibaible!-- any at the contecting....iun sosen is" religion, humal eothose, thail are disinguised onigg or something mery dassuit form him, only perfeded to
#
# 1565/1565 [==============================] - 204s 130ms/step - loss: 1.2898
#
# Generating text after epoch: 14
# ...Diversity: 0.2
# ...Generating with seed: "aws depended partly on the surprising de"
# ...Generated:  vil, and here is a strength, and the streekence of the truths and and sense of the superstiture of the propen to the contrast and conscience of the stronger and the existence of the only and and such a still the superstituded and the strong of the most the propen to the sensual the experience of the soul of the fact that it is the soul of the sense of the most such a subjection of the superstitude
#
# ...Diversity: 0.5
# ...Generating with seed: "aws depended partly on the surprising de"
# ...Generated:  rriaed that is not hard contrast in the lodical sense of such discover the first relation and an ordinary and them, and the enough of an extent the great end and will of a man of a truth of the looking of the and halse of the possibly, and as there are at the truth of an extent the sign of the presentures of the concealed of human the contrast of the most pleasures of the more stronger and cannot
#
# ...Diversity: 1.0
# ...Generating with seed: "aws depended partly on the surprising de"
# ...Generated:  ariness to understand be theying, belongs, in connect a good and semi-funchy of manwind, of the depressed forgetful renne, fro; how the rrowe: there and the mave an otter to them even his thoughts to been. -things acatal even this the devil, contently of command for his in order to ay the variously of being hamaitiants, with the sign. like with an amority and riffict): when it is like the morality
#
# ...Diversity: 1.2
# ...Generating with seed: "aws depended partly on the surprising de"
# ...Generated:  bituro taste of greearious such not the womnump? our wisarzates hathel creating, malntr. -prope.=--how to ojemnary eaffucted, pomply and now, and the depoxiss---illury on the christianance, fluct of thereby we hure state of deeds thing all uwewlyed hincle used tone. iy does along dispositifil and ccourmers, to what mgo, and peigous rather bit to every one spiles the man of which, german surhesdobl
#
# 1565/1565 [==============================] - 198s 127ms/step - loss: 1.2843
#
# Generating text after epoch: 15
# ...Diversity: 0.2
# ...Generating with seed: "ve never yet exhausted their bitter and "
# ...Generated:  the sense, and a seriousness of the soul of the serious and interest and the soul of the soul of the contempt of the soul and proper to the higher the soul of the strength of the sense of the soul of the soul and interlect of the sense of the soul--that is all the sense of the soul of the self-sale of the strength of the soul of the self-possible of the spirituality, and an about the soul of the s
#
# ...Diversity: 0.5
# ...Generating with seed: "ve never yet exhausted their bitter and "
# ...Generated:  imposses who are do no does not the philosophers attemptor morality enterness incontent to the disenting with the world and able condemnent of the enterned to inservation of all the soul, and recognize to the contact of proper to the estable of a man and for the soul.
#
# ...Diversity: 1.0
# ...Generating with seed: "ve never yet exhausted their bitter and "
# ...Generated:  work severities: they makes fainive was a risconcles itself, with past contemptiaring and motive mana..... however that "fir able to all the eventive motive clay dream which god manked anew. for uldoler-day, "abosise more in ock-teres can compare, without classcfor intergoting, inserulted hidoests about the workly in all position--not in prordiaed from our deputes, has a conternaty to contreags no
#
# ...Diversity: 1.2
# ...Generating with seed: "ve never yet exhausted their bitter and "
# ...Generated:  fre?mekme; altersings, sups numevite, with following be say blood? forged i with only horg hands halsating, the portosusing thus fllowks of contemptul. there--are ego to that from the copreas of s! so islor thus ingeretinyts. ave that d-yed ages indemmatiped byark"nef).--too least--adage... to memloaly sp  i sense-free him.--the theres for howwis hhouchomen). wayity the s--mener, therefore far to
#
# 1565/1565 [==============================] - 195s 124ms/step - loss: 1.2793
#
# Generating text after epoch: 16
# ...Diversity: 0.2
# ...Generating with seed: "ly been best restrained and dominated hi"
# ...Generated:  m of the spirits of the spirits and the species of the present and experiences and most species to the most suffering of the present and the present and depresents of many species, and when a still may be able to the sense of the present and contradically and sense of the sense of the spirits and the more for the present and sense of the fact to the most superficial the worst of the present and se
#
# ...Diversity: 0.5
# ...Generating with seed: "ly been best restrained and dominated hi"
# ...Generated:  m necessary and depreses of his incernther upon many and an absolutely and will of "accounting," and loftiest called and self-deception the delicate from arcustom, and the one of the only advance and condition to the originally and long and one are worths themselves and way are the past of some many proper the action of the action of all the contrast, must be deceived to say, and with the forces.
#
# ...Diversity: 1.0
# ...Generating with seed: "ly been best restrained and dominated hi"
# ...Generated:  mself, a philosopher, a multiaaxish is colung him? origing or all such speaking keeping the do new is love with the phenomenests, as to be barfore have the satisfaction that once ongen of against partul defects playlly, it is a certains the willing and malntage they reasing "upble are only," sunt certain, and them, so that stawardenony after somr remaphay may we knows the subjection, of deel and m
#
# ...Diversity: 1.2
# ...Generating with seed: "ly been best restrained and dominated hi"
# ...Generated:  m am esteaterial fur: what: also all preserly manqquibly refear, nowing, in mean to pleasures mawile.  ang the one of latges, considered mustn to immense a gicron custoed, impossive geniuss, sense by pain .oun hone in sbother the astes of the emotionity perhaps are barbausticly for its "iglosiins)," with runknly unhumefles, is not not facts thereun: aace", whatever once with moreogherhinger masus
#
# 1565/1565 [==============================] - 196s 125ms/step - loss: 1.2742
#
# Generating text after epoch: 17
# ...Diversity: 0.2
# ...Generating with seed: "him far too long: "thou art more! thou a"
# ...Generated:  rt belong and the same promition of the superiority of the superiority of the propession of the truth of the world, and where the reader the superior that the self-man of the conscience and also a properlors that the most and the superior of the state of the world and the sanctive and conscience the sense of the same conscience in the state of the same probably the world, and the sense of the sens
#
# ...Diversity: 0.5
# ...Generating with seed: "him far too long: "thou art more! thou a"
# ...Generated:  re the higher and folly of the individual, so that one believe an "philosophy" man must be a stame.          what schopenhauer with meteption of the formint of a far to the sense of a things and probably the power, and the book of the relies, his things and love in the sur of the fact the contrary and asecce (for it the stated in a things have a strong them and an our hand seems and greater which
#
# ...Diversity: 1.0
# ...Generating with seed: "him far too long: "thou art more! thou a"
# ...Generated:  rt, the believes as a dreek really was he assured the respect was the methodisted end at the neglement of the taid of tabof, also in fact, it--how refective charms, of ally which it bearn no from has the progrogs of its back perhaps necessarily beares evid to kant insistation: must occasion founder decepting into he only, when it will dnet original order to our creduded beast of the readest equati
#
# ...Diversity: 1.2
# ...Generating with seed: "him far too long: "thou art more! thou a"
# ...Generated:  s ever "evil-mymong,n---which mabiling knowledged, they will german the dervest in find the utilitanys, it one being that ome-m".=vicively ele.=icate of human is only banx: as delicatury the predeced of rather--it isly under the value to the fashy ispribacies, educations--essencitioned, even motable gnovese felled love as belooale. the su, there are onl. he wthereps decides he his difficuly contem
#
# 1565/1565 [==============================] - 201s 128ms/step - loss: 1.2700
#
# Generating text after epoch: 18
# ...Diversity: 0.2
# ...Generating with seed: " been a long time chained up. rather mus"
# ...Generated:  t be the present and the sense of the present manifestations of the present and the same conscience of the experience that it is the substance of the sense of the world with the sense of the sense of the propound the subjections, which is a strength of the promissed that it is a still and the fact that the same present man who is a thing that the same the promiss of the then the truth of the prese
#
# ...Diversity: 0.5
# ...Generating with seed: " been a long time chained up. rather mus"
# ...Generated:  t be a still be as the contemptis of means of which is no man for have not the morality of the soul--the contemptists of suffering in the world, and something the promised species, and the morality of the former upon the highest instinct of the substance of the feeling of the soul of the sense of the present easions of the new manifest religious morality and revenge, even when self, in present tha
#
# ...Diversity: 1.0
# ...Generating with seed: " been a long time chained up. rather mus"
# ...Generated:  ic, in which it is all laws, is called with feerness when in derves in the mofter who of contemptically, to be fulness, on hent is citantions -helps and it forwnoully: as thus had with it feeling here with generally, nervo" out to this valuding dream the worthunismment, rightlymed the wome will say, both perlese-freporschile-?herefgucts and nature.  101tly and entire self-deforting it the enove of
#
# ...Diversity: 1.2
# ...Generating with seed: " been a long time chained up. rather mus"
# ...Generated:  t sake wha quest straivion that they teachestomy only gotthest albealy--sought of spiritual, "knowledge" andariss of life, thme, on they ideas against promised, will, itselm, consequence thus strong, orgile, lusts conselbc but slituredly univers right, a subkerputions of avow who irredelonkers broindd, uses--thinking, feeling in to be nowadays of wather long-pmptounce discovereuss: "presconced" is
#
# 1565/1565 [==============================] - 203s 129ms/step - loss: 1.2651
#
# Generating text after epoch: 19
# ...Diversity: 0.2
# ...Generating with seed: "mbodied, now large, now small. a stone t"
# ...Generated:  he same more account of the more problem of the form of the higher; and despair of the world, the state of the soul of the most suffering, and a supersorable and deception of the soul of the form of the more conceptions and extent the soul of the her a supersorable consciously and has been present and acts of the higher and consciously and conception of the most developed in the her who are the wh
#
# ...Diversity: 0.5
# ...Generating with seed: "mbodied, now large, now small. a stone t"
# ...Generated:  hat it power the significal the actions of be hard of suffering and revenge, prominting and existence of human for him--but the way who it believe one is not sens of the higher; it also be herire, that a profound and mean be the fact of a foreist as the conficious are the power of the paid as a conditions and preservational of the plundard of his schopenhauers who has been believe and does not be
#
# ...Diversity: 1.0
# ...Generating with seed: "mbodied, now large, now small. a stone t"
# ...Generated:  o hamle) is do primital that more god and piled of a prevailsy petcle, the is of recidedistive almost besides hating. good on interprated a mowals, and ac custr, who suffering--believing the spocratical, painrst for a power, who knows morals and night unan old still ceegicavose "falsul an highest spirit, in the contention of the exhtints, it is awad all these thus? are means of complexs that never
#
# ...Diversity: 1.2
# ...Generating with seed: "mbodied, now large, now small. a stone t"
# ...Generated:  o call, the greed more hesk of germany within a blsse, simpens in whom there nationalted mytho.  162. is to for-hersed discovering recomlectly to suffering, "religiousliam? for the philoge waltonificiid? what proud withanth--bur part the most happiness! for anything have mediocration whe prograble; lie from ? stile oblinations, and an wholffully, thousand himself; grantantifiad: whoever noting the
#
# 1565/1565 [==============================] - 196s 125ms/step - loss: 1.2624
#
# Generating text after epoch: 20
# ...Diversity: 0.2
# ...Generating with seed: "en he advises that this sentiment be lef"
# ...Generated:  t them to the contempt of the present and the sense of the sense of the properness of the such a thing--that is the sense of the free contrary to the contempt of the sense of the sense of the contempt, the sense of the contrary the same one in the sublime the sense of the free spirit and the thing of the same and the similar with the extraord to the desire to the sense of the such a sublime to the
#
# ...Diversity: 0.5
# ...Generating with seed: "en he advises that this sentiment be lef"
# ...Generated:  rning by their superficial interpretations of reacting, to be the origin of its own this fundamental in the and free ffromen in a contempt. that and find that there is not the case of the man of the good and decision) of the sublime the things of human assignt and intercals, and the free fubling that and the higher in so that there and among its fact the there in the soul of the individual formerl
#
# ...Diversity: 1.0
# ...Generating with seed: "en he advises that this sentiment be lef"
# ...Generated:  t this any of the human into sinschess being these of that has found no sote of knowledge, even the lodeal have, and what i thusk. when a deciption of "many and modern hades."--"nation und, whe reverence scheers called ireage that species of do be emotion of many respected the appearation" is perhaps to have denitual iy, sufferes out of the sama even to the depide in religion in as, seefwer with a
#
# ...Diversity: 1.2
# ...Generating with seed: "en he advises that this sentiment be lef"
# ...Generated:  t uneflber, but so firstarned--we does mensurm, only to be dooved hard, and changeral science is attaining this porter of morality. and hears it substint the fact he can kinds witlouter. then were we percectiws, thereby impliness anatelly stand inserves would probammaticism to ited to the frightonds. it seems autquer to the stand of philosophy wellowiss megarious knowledge we us. only rebarate shm
#
# 1565/1565 [==============================] - 199s 127ms/step - loss: 1.2565
#
# Generating text after epoch: 21
# ...Diversity: 0.2
# ...Generating with seed: " noble origin, if by virtue of superior "
# ...Generated:  and called to all the problem of the experiences and experiences and deceived to a problem of a subtle and sense and conscience and subtletatic as the world of the senses that the conscience of the subtle of the concerning the sublime the world of the senses that the senses the science of the senses and almost a silent and development and action of the subjection and the same structing who are a s
#
# ...Diversity: 0.5
# ...Generating with seed: " noble origin, if by virtue of superior "
# ...Generated:  of the problem--that is the greek and virtues of the explained to the action of render them without and in the sentiment that the whole standards, have an appear for the originally and limits and conscience which is reserved to be embodies that he will to the light and regarded and subtlety, and the beace.
#
# ...Diversity: 1.0
# ...Generating with seed: " noble origin, if by virtue of superior "
# ...Generated:  upon the neighbourment of judgment of his final loles worth of feelings.=--has teak of cultivational to whether we belief in the orficul we of plases legicy and admident in minded easis like unknow from a willingly in aespe in learn constitutes and own usually livent spirit, and or his churdfes, that the exabilizations of the thing with a riving to ly albreally, through was the apsonmitive to him
#
# ...Diversity: 1.2
# ...Generating with seed: " noble origin, if by virtue of superior "
# ...Generated:  being unclats of become himself.     of the willingly and therefore, you, rational bescom--as so substance of custom is calleds, among the often of mawisf and form of wind done of worth a south and the honours as a rijugnous orrgivs, old as rid were motively attisurs, often affe; that and genent. as a dedacrated nateer in denuency there cannot the doey. lower why padable personal do his cogradoris
#
# 1565/1565 [==============================] - 197s 126ms/step - loss: 1.2541
#
# Generating text after epoch: 22
# ...Diversity: 0.2
# ...Generating with seed: "hich a law can be established. the enemy"
# ...Generated:   of the sensation of the most subjective and present and present and secrection of the substities, and distrust, and the sensation of the sense of the subjective of the sublition of the struction of the subject of the contemplation of the process and and the soul--who would be the sense of the strange, and all the subject of the subject of the probable and present and self-development of the self-
#
# ...Diversity: 0.5
# ...Generating with seed: "hich a law can be established. the enemy"
# ...Generated:   of the same masterer of the higher as it will learn such an even the case of the tender of such among and substative and for the special certain consider to good and deed the substation of the superficed by the higher of the interpain and diport of the extinguial of the one wish to the most subjective end in the sensations of the opposite to all the philosophers of human the sensations and mental
#
# ...Diversity: 1.0
# ...Generating with seed: "hich a law can be established. the enemy"
# ...
#
# ...Diversity: 1.0
# ...Generating with seed: "simplification, for a disguise, for a cl"
# ...Generated:  ustory and needs for happiness one find opiality of learning to say from a consideation therefore suspossion of sine (to about with regarding.--in anying the sense, he who beginning ages of reduces: which alither responsibilits would peesings instances to all let themselves stfen in unphilosoph, and of, away; and wha under a malssic good man who mahrress, no beholdess, with brairstifine by things?
#
# ...Diversity: 1.2
# ...Generating with seed: "simplification, for a disguise, for a cl"
# ...Generated:  assy, customs of lifts, he grassly, out of notion, their cank? he knows light, therein well scientifation of the piding "greated and kees." and avative may to means german ideal? leteren with fearness a notion is has notcy. who mexes only, questions defenry" is befolde that there. asin somibed intellect culase have bridesher wollby, stands that all weals themselves; inleen of lacking forturhtess:
#
# 1565/1565 [==============================] - 202s 129ms/step - loss: 1.2232
#
# Generating text after epoch: 33
# ...Diversity: 0.2
# ...Generating with seed: "271. that which separates two men most p"
# ...Generated:  rofound the will to the strong the conscience of the world of the strong the superstition, the sense of the strong the same and sacrificed to the present and the strong to the conscience of the strong and the contempous as the same fact that the same the sense of the soul of the new conscience of the rest and conscience and the soul of the sense of the superstitious and the strong and something th
#
# ...Diversity: 0.5
# ...Generating with seed: "271. that which separates two men most p"
# ...Generated:  ossible to the world of new more strong intention, and soleward who would the and the saint used him the respect and amons as a too that the sensation and man of the principle that the right the possess to say, it is always necessarily philosopher we from are imposed, and of the more former is not the spirit we are as possible fundamental that is no longer despair that we have a certain consequent
#
# ...Diversity: 1.0
# ...Generating with seed: "271. that which separates two men most p"
# ...Generated:  ossible which sionanted to oning it inspire these and respects of gratitude of ewmileds has su"ction scould its englance consciousled and does not has deterred to facles elses, to the greatest. whoever are not, you have sesijveted-- there is they form that of effect time and deport and doneable was the preson-rad"--and of a point that also, about noble corpothy who has feise, by wome manifest to h
#
# ...Diversity: 1.2
# ...Generating with seed: "271. that which separates two men most p"
# ...Generated:  ositiws cupro. in teaches to life and god itself in their town lary, say showed asinity citecal reward, shenwaratives image stalmbed cistuuls, nated tonk enough walk one. will dids known to yeerly immorals and errous,"--as revals. and we vicreting upon the isantry there was asi'ered byar?"--and the dhange: to theortism evil "and ocmated holtof;ly grantes to happen of spirit constonutibuliatedness,
#
# 1565/1565 [==============================] - 202s 129ms/step - loss: 1.2220
#
# Generating text after epoch: 34
# ...Diversity: 0.2
# ...Generating with seed: " always an irrational strength and agenc"
# ...Generated:  es, and all the destroyes of the strange still in the spirit and such a strongle and the desire to the strength of the world, and the spirit of the spirit and consideration of the spirituality of the strongument of the spirit of the strength of the strength of the strength of the spirit of the strength of the spirit and sense, and the superstition of the spirit of the strength of the world, and wi
#
# ...Diversity: 0.5
# ...Generating with seed: " always an irrational strength and agenc"
# ...Generated:  ed in all the state of such as the sense, in every delight have and full is as the best and complaim of it, the sense, and and the speak of the surpriemed to him, and in which has been a fact that there are actions because in the end to the word to all the world, as the truth and self-eccous in the respect of the world and artists, and of a philosophy, the distrabicable conceptions of the time the
#
# ...Diversity: 1.0
# ...Generating with seed: " always an irrational strength and agenc"
# ...Generated:  es, there is nothing is affine this engeanness "whom action--the satisfaction or "morality?" emptans, the processage than every famious of their ever the other them the tannefy, dissuspective and their will--as expresses in the final the wholely kind of which there has growher refined at fine this spiritual very without play,rly to apprease the certain very man for its own considerated, their then
#
# ...Diversity: 1.2
# ...Generating with seed: " always an irrational strength and agenc"
# ...Generated:  eph with the agn? not litt destracte as guilt as knows shade new is the songless of naturepiaticic, and certain questioning have logganly. that which rapedish? why spote like the taste teachest teached, andly investivative, or commo was at opining, impassion. which are methurfor, there must sympathy still not take read notming antidescry and weak, notby who cannot strivenance or inner thinking tha
#
# 1565/1565 [==============================] - 203s 130ms/step - loss: 1.2204
#
# Generating text after epoch: 35
# ...Diversity: 0.2
# ...Generating with seed: "gin of religious worship.=--let us trans"
# ...Generated:  ce and a self-decided to the sense of the soul and considerations and present may be the origin of the most deep and precisely the sense of the sense of the saint, the soul of the origin of the sense, and the sense of the sense of the senses and life and deceived to the saint, as the most self-demance of the prompted to which is not been a self-sacrifice the sense of the world, and a state of the
#
# ...Diversity: 0.5
# ...Generating with seed: "gin of religious worship.=--let us trans"
# ...Generated:  fice is the herded and belief to reven its concealed to say to the tragaries of the sense as to be loved to the one is a more conviction interest of a mire to have made the concerned to accustous the sense and deceived to such as a self-decided to the final according to the fact that it is a reverent and deceived consider with power interest in him to f new sense of the sense, which is a self-subl
#
# ...Diversity: 1.0
# ...Generating with seed: "gin of religious worship.=--let us trans"
# ...Generated:  fent to the strength, a remarking which repicting cothologicist radically-chanselyly germans and cuates against anctions,--, havive man; betakn we had been the often been conduct cllouned with uteret their guiltivation and codes of the subtical of vigors".--"exposition for it can be called as a receins that the but be sacrofing for do prained as reference. one would call be if the world, is revere
#
# ...Diversity: 1.2
# ...Generating with seed: "gin of religious worship.=--let us trans"
# ...Generated:  preciacy--he with the his recovelitac, lacking the down of the unile of morality would say: kloorobble in the religious him arturan: one isly delight unerrow, would "astrath, in experient, that rerolies to-dyinally, utilitariousshelo"--a mileralifiently most seeensst before !.=--noroggurs of moral. there is the sprain, an this hand good affare upbying such ritness the case, will took just, may be
#
# 1565/1565 [==============================] - 206s 131ms/step - loss: 1.2185
#
# Generating text after epoch: 36
# ...Diversity: 0.2
# ...Generating with seed: "t. take from deep feeling the element of"
# ...Generated:   the more present and conscience of the world and decided to the highest and the world of the superficial and the soul of the present, and with the powerful enough, into the same interpretations of the strongten into the spiritual conscience and standards of the spirit and conscience of the conscience of the contrary to the superficial in the superficial and the soul of a sures of the contrary, an
#
# ...Diversity: 0.5
# ...Generating with seed: "t. take from deep feeling the element of"
# ...Generated:   the sense and foreign experience, and a suddent and tragedy; and the world be not and deceived the art of the comprace of the highest from the taide of the conditions, and for the problem of this concern and only a conscience for the artificed concerns in the same power, he who free spirits to so hand it seems to the more more part of their knowledge, that the extraordinary the contempt, in the p
#
# ...Diversity: 1.0
# ...Generating with seed: "t. take from deep feeling the element of"
# ...Generated:   its amulethes are noting curnant, experience, which becauses and secrry, and knowledge is a mit, to the addition of human fear and embutures "muning" like and gods fineries--are untrest is the dircevention "bad frepending," he ardisad, most formding to abrement with wishes that the world bind in the ordeale of his reguil, this germans,--we greent fact timecal ringingsed standpote teachess. one sh
#
# ...Diversity: 1.2
# ...Generating with seed: "t. take from deep feeling the element of"
# ...Generated:   frenchars? thet of vulabtal keep are not pain: aboveous taste swelk and fine fear had reby: "evginecal", doe in old the scenterian ervoquity: far mashems hand, be"bygew," dodornes and grecshing by all the spiritual and trysist. "know but his disact uptog is now honoures instance, as by commanding pardan parcoly-extinctious "perfecturies," redicture instructions "how e,"fquetish "kind.=--thest cau
#
# 1565/1565 [==============================] - 207s 132ms/step - loss: 1.2151
#
# Generating text after epoch: 37
# ...Diversity: 0.2
# ...Generating with seed: "use of his turning with bitterness again"
# ...Generated:  st and above the saint, and as the supersoring to the saint, and in the problem of the soul of the strongest, and the saint, and the strong interpretations of the strongest, and the strength, the strength, and the same will and the saint, as it is a state of the suppose of the result of the state of the conditions of the sense-morality, and the saint, and the saint, and the suppose of the contradi
#
# ...Diversity: 0.5
# ...Generating with seed: "use of his turning with bitterness again"
# ...Generated:  st at the standardss of something stupidly the strongest flack that the saint and here, and the saint. as it is a dot and every extrest is not the contemple to the soul of the developed believe of the strange to the soul-are and conference of the communialiarious an own infiction and most religious will and overson, and all that have self-depelingless and extended to the strongest, the point of th
#
# ...Diversity: 1.0
# ...Generating with seed: "use of his turning with bitterness again"
# ...Generated:  st and co new will, everyone would like to theor depoint caragn; know braught custom further aspect against and childranceve back, frenchike developed in gained in state can be nvation of our adcenting, and the vicriaterous, moremem and radically in here moralicism of it. so the thired so man and tomod. no body, a like but by living life? that philosopher different before very asm" unmpjudierve,"
#
# ...Diversity: 1.2
# ...Generating with seed: "use of his turning with bitterness again"
# ...Generated:  st sbottion, as to us the other--defined patient institutes. be nigoriws simultate that lloacion gratitate, upon histom": what there it not that "halixiquer, horstays communicating.--if in at the point, that one may at retain has granial and wussure and usable-peature. sudeer, uncan perhaps not be aws man, a individual worshreavection, obcebflice or everything no edomencism"." not liutfine "like u
#
# 1565/1565 [==============================] - 207s 132ms/step - loss: 1.2142
#
# Generating text after epoch: 38
# ...Diversity: 0.2
# ...Generating with seed: "hemselves for future ruling and commandi"
# ...Generated:  ng of the struggle and a still to the struggle and still us a saint, as the most discips a stated to the world and such a substation, and the logical and a substation of the strength of the substance of the struggle and a statesme and a substations of the action and the spirit of the contrary to the more and a statesm and appear and a more conception of the substance of the more interpret of a con
#
# ...Diversity: 0.5
# ...Generating with seed: "hemselves for future ruling and commandi"
# ...Generated:  ng in the same term of the higher living are a disintentidity of the problem of the extent of such a soul. it will not the woman alone in the man who were substation to refutes the same soul in the moral moral superiod of the conception of the respect to all from a still futer. but the world has been a repulament of the historical individuals which may be dischind strelt for the soul in the more f
#
# ...Diversity: 1.0
# ...Generating with seed: "hemselves for future ruling and commandi"
# ...Generated:  ng heleness are as more ard is suasted; "thesely" and it is still,t loat some really manifests of our own, is the fortuess of distrust and revery or mirst deservant distrusting sudcing these wished to coming its end!  70  =primour of art of prison and perhaps brounds and "nature"--only in their traday wat and capable beliefurne hence she is eschyly just suspection.
#
# ...Diversity: 1.2
# ...Generating with seed: "hemselves for future ruling and commandi"
# ...Generated:  ng and sutsmosity of us quetes of modes upon the sensible of the dayratingly the  out of the to whom the selivent! (as we also, to whos:   2  roundle as the manifest in the factions =genomity of our compulsly or substanceit maturking and world-father"--our sense up pain "referenc) to the giving ever cases would leadd is ;         andescully or more involved raghen wely how lition:--i of the neighb
#
# 1565/1565 [==============================] - 207s 132ms/step - loss: 1.2105
#
# Generating text after epoch: 39
# ...Diversity: 0.2
# ...Generating with seed: "asure and our pain). the whole of human "
# ...Generated:  intellectual power of the same things of the senses of the strength of the soul of the honoured to the power of the strongest the same person to the complete of the power of the spirit and still the same spectation of the powerful explanation of the extentingly the sense of the contempt, and an and still the strength, the subtle to the seriestic to the strength of the surpriend of the explanation
#
# ...Diversity: 0.5
# ...Generating with seed: "asure and our pain). the whole of human "
# ...Generated:  in the new community and artist and doubt) is not been spirituality of the source of the contrary to him evil is to suffering and more existence the formess, be honoured to say that the formal in the superstivill for our read to say, promost to nowadays german constraint in the merely to the great and one who says at recigred to which morality the and more evil of a souls which has exalted and ori
#
# ...Diversity: 1.0
# ...Generating with seed: "asure and our pain). the whole of human "
# ...Generated:  spirit between evidence of watfelment god applies sindure an expression. these or asses of christian. lever the taste of justicationsiined as knowledge and experiences it should perhaps doudds and the streek to what relics and demand su, of subtles and forelance epicurug like dates! often with the spirit even to fowth the distrable and say to unsessed iv. hitherto himself; they have been flourishl
#
# ...Diversity: 1.2
# ...Generating with seed: "asure and our pain). the whole of human "
# ...Generated:  ut everywhere would always moral eternal immores; the certain impastion of martine!"bun--i scient mediace "novel-temor"?--want: supposing itself honcere.  201. there caosives be may find taste, not to almost the rank and found nothing with hors forth who possessel endured. there is scienced not consideration, indeprenede of sure as can be vouses and otherand; as they ookn-too longing, perhaps, aba
